# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import seaborn as sns
import platform

# %%
# seaborn 설정 리셋
sns.reset_defaults()

# 폰트설정
if platform.system() == 'Windows' :
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else :
    print('Check your OS System')
    
# 그래프에 마이너스 표시
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
file_path = "./data/직업별_취업자_20220728110427.xlsx"
data = pd.read_excel(file_path)
data
# Out:
#                  직업별  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0              1 관리자   409   404   358   335   313   371   408   395   393
# 1     2 전문가 및 관련 종사자  4968  5129  5189  5291  5427  5491  5557  5480  5585
# 2           3 사무 종사자  4271  4374  4446  4558  4663  4762  4749  4691  4751
# 3          4 서비스 종사자  2645  2779  2813  2888  2946  2969  3116  3046  3073
# 4           5 판매 종사자  3074  3154  3129  3121  3091  3037  3030  2897  2766
# 5      6 농림어업 숙련 종사자  1420  1357  1243  1186  1198  1266  1332  1383  1396
# 6   7 기능원 및 관련 기능종사자  2254  2291  2375  2396  2384  2347  2372  2336  2406
# 7  8 장치,기계조작 및 조립종사자  3038  3111  3187  3194  3171  3098  3026  2957  2979
# 8         9 단순노무 종사자  3222  3299  3437  3440  3533  3483  3534  3718  3925

# %%
data = data.transpose()
data
# Out:
#           0               1         2          3         4              5  \
# 직업별   1 관리자  2 전문가 및 관련 종사자  3 사무 종사자  4 서비스 종사자  5 판매 종사자  6 농림어업 숙련 종사자
# 2013    409            4968      4271       2645      3074           1420
# 2014    404            5129      4374       2779      3154           1357
# 2015    358            5189      4446       2813      3129           1243
# 2016    335            5291      4558       2888      3121           1186
# 2017    313            5427      4663       2946      3091           1198
# 2018    371            5491      4762       2969      3037           1266
# 2019    408            5557      4749       3116      3030           1332
# 2020    395            5480      4691       3046      2897           1383
# 2021    393            5585      4751       3073      2766           1396
#
#                      6                  7           8
# 직업별   7 기능원 및 관련 기능종사자  8 장치,기계조작 및 조립종사자  9 단순노무 종사자
# ...

# %%
data = data.iloc[1:,:]
data
# Out:
#         0     1     2     3     4     5     6     7     8
# 2013  409  4968  4271  2645  3074  1420  2254  3038  3222
# 2014  404  5129  4374  2779  3154  1357  2291  3111  3299
# 2015  358  5189  4446  2813  3129  1243  2375  3187  3437
# 2016  335  5291  4558  2888  3121  1186  2396  3194  3440
# 2017  313  5427  4663  2946  3091  1198  2384  3171  3533
# 2018  371  5491  4762  2969  3037  1266  2347  3098  3483
# 2019  408  5557  4749  3116  3030  1332  2372  3026  3534
# 2020  395  5480  4691  3046  2897  1383  2336  2957  3718
# 2021  393  5585  4751  3073  2766  1396  2406  2979  3925

# %%
data = data.reset_index()
data
# Out:
#   index    0     1     2     3     4     5     6     7     8
# 0  2013  409  4968  4271  2645  3074  1420  2254  3038  3222
# 1  2014  404  5129  4374  2779  3154  1357  2291  3111  3299
# 2  2015  358  5189  4446  2813  3129  1243  2375  3187  3437
# 3  2016  335  5291  4558  2888  3121  1186  2396  3194  3440
# 4  2017  313  5427  4663  2946  3091  1198  2384  3171  3533
# 5  2018  371  5491  4762  2969  3037  1266  2347  3098  3483
# 6  2019  408  5557  4749  3116  3030  1332  2372  3026  3534
# 7  2020  395  5480  4691  3046  2897  1383  2336  2957  3718
# 8  2021  393  5585  4751  3073  2766  1396  2406  2979  3925

# %%
data.columns = ['연도','관리자', '전문가 및 관련 종사자', '사무 종사자', '서비스 종사자', '판매 종사자', '농림어업 숙련 종사자', '기능원 및 관련 기능종사자', '장치,기계조작 및 조립종사자', '단순노무 종사자']
data
# Out:
#      연도  관리자 전문가 및 관련 종사자 사무 종사자 서비스 종사자 판매 종사자 농림어업 숙련 종사자 기능원 및 관련 기능종사자  \
# 0  2013  409         4968   4271    2645   3074        1420           2254
# 1  2014  404         5129   4374    2779   3154        1357           2291
# 2  2015  358         5189   4446    2813   3129        1243           2375
# 3  2016  335         5291   4558    2888   3121        1186           2396
# 4  2017  313         5427   4663    2946   3091        1198           2384
# 5  2018  371         5491   4762    2969   3037        1266           2347
# 6  2019  408         5557   4749    3116   3030        1332           2372
# 7  2020  395         5480   4691    3046   2897        1383           2336
# 8  2021  393         5585   4751    3073   2766        1396           2406
#
#   장치,기계조작 및 조립종사자 단순노무 종사자
# 0            3038     3222
# 1            3111     3299
# 2            3187     3437
# 3            3194     3440
# 4            3171     3533
# 5            3098     3483
# ...

# %%
# data = data.set_index("연도별")
# data

# %%
# data = data[['전문가 및 관련 종사자', '사무 종사자', '서비스 종사자', '판매 종사자','기능원 및 관련 기능종사자', '장치,기계조작 및 조립종사자', '단순노무 종사자']]

# %%
file_path = "./data/직업별_취업자_20220728111209_분석(전년_대비_증감_(증감률)).xlsx"
data_per = pd.read_excel(file_path)
data_per
# Out:
#                  직업별            2014            2015            2016  \
# 0                직업별  전년 대비 증감 (증감률)  전년 대비 증감 (증감률)  전년 대비 증감 (증감률)
# 1                  계            -2.4            -1.1            -0.9
# 2     2 전문가 및 관련 종사자            -3.3            -1.2              -2
# 3           3 사무 종사자            -2.4            -1.7            -2.5
# 4          4 서비스 종사자              -5            -1.3            -2.7
# 5           5 판매 종사자            -2.6             0.8             0.2
# 6      6 농림어업 숙련 종사자             4.4             8.4             4.6
# 7   7 기능원 및 관련 기능종사자            -1.6            -3.7            -0.9
# 8  8 장치,기계조작 및 조립종사자            -2.4            -2.5            -0.2
# 9         9 단순노무 종사자            -2.4            -4.2            -0.1
#
#              2017            2018            2019            2020  \
# 0  전년 대비 증감 (증감률)  전년 대비 증감 (증감률)  전년 대비 증감 (증감률)  전년 대비 증감 (증감률)
# 1            -1.2            -0.4            -1.1             0.8
# ...

# %%
# 행/열 자리바꾸기
data_per = data_per.T
data_per
# Out:
#                    0    1               2         3          4         5  \
# 직업별              직업별    계  2 전문가 및 관련 종사자  3 사무 종사자  4 서비스 종사자  5 판매 종사자
# 2014  전년 대비 증감 (증감률) -2.4            -3.3      -2.4         -5      -2.6
# 2015  전년 대비 증감 (증감률) -1.1            -1.2      -1.7       -1.3       0.8
# 2016  전년 대비 증감 (증감률) -0.9              -2      -2.5       -2.7       0.2
# 2017  전년 대비 증감 (증감률) -1.2            -2.6      -2.3         -2         1
# 2018  전년 대비 증감 (증감률) -0.4            -1.2      -2.1       -0.8       1.8
# 2019  전년 대비 증감 (증감률) -1.1            -1.2       0.3         -5       0.2
# 2020  전년 대비 증감 (증감률)  0.8             1.4       1.2        2.2       4.4
# 2021  전년 대비 증감 (증감률) -1.4            -1.9      -1.3       -0.9       4.5
#
#                   6                 7                  8           9
# 직업별   6 농림어업 숙련 종사자  7 기능원 및 관련 기능종사자  8 장치,기계조작 및 조립종사자  9 단순노무 종사자
# 2014            4.4              -1.6               -2.4        -2.4
# ...

# %%
data_per = data_per.iloc[1:,1:]
data_per
# Out:
#         1    2    3    4    5    6    7    8    9
# 2014 -2.4 -3.3 -2.4   -5 -2.6  4.4 -1.6 -2.4 -2.4
# 2015 -1.1 -1.2 -1.7 -1.3  0.8  8.4 -3.7 -2.5 -4.2
# 2016 -0.9   -2 -2.5 -2.7  0.2  4.6 -0.9 -0.2 -0.1
# 2017 -1.2 -2.6 -2.3   -2    1   -1  0.5  0.7 -2.7
# 2018 -0.4 -1.2 -2.1 -0.8  1.8 -5.7  1.6  2.3  1.4
# 2019 -1.1 -1.2  0.3   -5  0.2 -5.2 -1.1  2.3 -1.4
# 2020  0.8  1.4  1.2  2.2  4.4 -3.8  1.5  2.3 -5.2
# 2021 -1.4 -1.9 -1.3 -0.9  4.5 -0.9   -3 -0.7 -5.6

# %%
data_per = data_per.reset_index()
data_per
# Out:
#   index    1    2    3    4    5    6    7    8    9
# 0  2014 -2.4 -3.3 -2.4   -5 -2.6  4.4 -1.6 -2.4 -2.4
# 1  2015 -1.1 -1.2 -1.7 -1.3  0.8  8.4 -3.7 -2.5 -4.2
# 2  2016 -0.9   -2 -2.5 -2.7  0.2  4.6 -0.9 -0.2 -0.1
# 3  2017 -1.2 -2.6 -2.3   -2    1   -1  0.5  0.7 -2.7
# 4  2018 -0.4 -1.2 -2.1 -0.8  1.8 -5.7  1.6  2.3  1.4
# 5  2019 -1.1 -1.2  0.3   -5  0.2 -5.2 -1.1  2.3 -1.4
# 6  2020  0.8  1.4  1.2  2.2  4.4 -3.8  1.5  2.3 -5.2
# 7  2021 -1.4 -1.9 -1.3 -0.9  4.5 -0.9   -3 -0.7 -5.6

# %%
data_per.columns = ['연도','종사자 전체', '전문가 및 관련 종사자', '사무 종사자', '서비스 종사자', '판매 종사자', '농림어업 숙련 종사자', '기능원 및 관련 기능종사자', '장치,기계조작 및 조립종사자', '단순노무 종사자']
data_per
# Out:
#      연도 종사자 전체 전문가 및 관련 종사자 사무 종사자 서비스 종사자 판매 종사자 농림어업 숙련 종사자 기능원 및 관련 기능종사자  \
# 0  2014   -2.4         -3.3   -2.4      -5   -2.6         4.4           -1.6
# 1  2015   -1.1         -1.2   -1.7    -1.3    0.8         8.4           -3.7
# 2  2016   -0.9           -2   -2.5    -2.7    0.2         4.6           -0.9
# 3  2017   -1.2         -2.6   -2.3      -2      1          -1            0.5
# 4  2018   -0.4         -1.2   -2.1    -0.8    1.8        -5.7            1.6
# 5  2019   -1.1         -1.2    0.3      -5    0.2        -5.2           -1.1
# 6  2020    0.8          1.4    1.2     2.2    4.4        -3.8            1.5
# 7  2021   -1.4         -1.9   -1.3    -0.9    4.5        -0.9             -3
#
#   장치,기계조작 및 조립종사자 단순노무 종사자
# 0            -2.4     -2.4
# 1            -2.5     -4.2
# 2            -0.2     -0.1
# 3             0.7     -2.7
# 4             2.3      1.4
# 5             2.3     -1.4
# 6             2.3     -5.2
# 7            -0.7     -5.6

# %%
color = ['#F2B117','#F2B117','#F2B117','navy','navy','#F2B117','#F2B117','#F2B117','navy']
# ylist = np.arange(0, 5000, 500)
fig = plt.figure(figsize=(20,10))
plt.plot(data_per['연도'],data_per['서비스 종사자'])
plt.plot(data_per['연도'],data_per['종사자 전체'])
# plt.yticks(ylist)

plt.show()

# %%
color = ['#F2B117','#F2B117','#F2B117','navy','navy','#F2B117','#F2B117','#F2B117','navy']
ylist = np.arange(0, 5000, 500)
fig = plt.figure(figsize=(20,10))
plt.bar(data['연도'],data['서비스 종사자'])
plt.yticks(ylist)

plt.show()

# %%
color = ['#F2B117','#F2B117','#F2B117','navy','navy','#F2B117','#F2B117','#F2B117','navy']
data.plot(title = 'SomeTitle', figsize=(20,10), legend = True, marker = 'o', rot=0, color = color)


plt.xlabel('연도')
plt.ylabel('증감율')
plt.title('직종별 취업자 증감율')

plt.show()

#
