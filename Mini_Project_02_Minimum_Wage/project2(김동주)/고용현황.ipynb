# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import seaborn as sns
import platform

# %%
# seaborn 설정 리셋
sns.reset_defaults()

# 폰트설정
if platform.system() == 'Windows' :
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else :
    print('Check your OS System')
    
# 그래프에 마이너스 표시
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
file_path = "./data/산업_규모별_고용_20220721112015.xlsx"
data = pd.read_excel(file_path)
data
# Out:
#                                  산업분류  종사자_전체 (명)  근로자_상용 (명)  근로자_임시일용 (명)  \
# 0                                  전체    18148819    15243271       1769714
# 1                         B.광업(05~08)       13380       12872           328
# 2                        C.제조업(10~34)     3714033     3588021        102182
# 3        D.전기, 가스, 증기 및 공기 조절 공급업(35)       63529       62599           803
# 4    E.수도, 하수 및 폐기물 처리, 원료 재생업(36~39)      105290      101575          3265
# 5                        F.건설업(41~42)     1337651      865205        451229
# 6                   G.도매 및 소매업(45~47)     2259258     1817042        169350
# 7                   H.운수 및 창고업(49~52)      721161      634342         18334
# 8                  I.숙박 및 음식점업(55~56)     1224015      811012        399402
# 9                      J.정보통신업(58~63)      585773      545972         16550
# 10                  K.금융 및 보험업(64~66)      757618      454479          8199
# ...

# %%
# 년도별 데이터 분할

dt_2018 = data.iloc[0:,:8]
dt_2019 = data.iloc[0:,8:16]
dt_2020 = data.iloc[0:,16:24]
dt_2021 = data.iloc[0:,24:32]

# %%
# 열 이름 변경
dt_2018.columns = ["산업분류","종사자_전체","근로자_상용","근로자_임시일용","종사자_기타","채용_전체","채용_상용","채용_임시일용"]
dt_2019.columns = ["산업분류","종사자_전체","근로자_상용","근로자_임시일용","종사자_기타","채용_전체","채용_상용","채용_임시일용"]
dt_2020.columns = ["산업분류","종사자_전체","근로자_상용","근로자_임시일용","종사자_기타","채용_전체","채용_상용","채용_임시일용"]
dt_2021.columns = ["산업분류","종사자_전체","근로자_상용","근로자_임시일용","종사자_기타","채용_전체","채용_상용","채용_임시일용"]

# %%
dt_18 = dt_2018[["산업분류","종사자_전체"]]
dt_19 = dt_2019[["산업분류","종사자_전체"]]
dt_20 = dt_2020[["산업분류","종사자_전체"]]
dt_21 = dt_2021[["산업분류","종사자_전체"]]

# %%
# 조인, 열이름 변경
dt_1 = pd.merge(dt_18,dt_19,how="inner",on= "산업분류")
dt_2 = pd.merge(dt_1,dt_20,how="inner",on= "산업분류")
dt_3 = pd.merge(dt_2,dt_21,how="inner",on= "산업분류")
dt_3
dt_3.columns = ["산업분류","18_종사자_전체","19_종사자_전체","20_종사자_전체","21_종사자_전체"]
dt_3
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11652\3289508188.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'종사자_전체_x'} in the result is deprecated and will raise a MergeError in a future version.
#   dt_3 = pd.merge(dt_2,dt_21,how="inner",on= "산업분류")
#                                  산업분류  18_종사자_전체  19_종사자_전체  20_종사자_전체  \
# 0                                  전체   18148819   18699465   18591325
# 1                         B.광업(05~08)      13380      12889      12338
# 2                        C.제조업(10~34)    3714033    3732281    3666936
# 3        D.전기, 가스, 증기 및 공기 조절 공급업(35)      63529      65687      68608
# 4    E.수도, 하수 및 폐기물 처리, 원료 재생업(36~39)     105290     110367     114745
# 5                        F.건설업(41~42)    1337651    1375391    1382362
# 6                   G.도매 및 소매업(45~47)    2259258    2319243    2268010
# 7                   H.운수 및 창고업(49~52)     721161     731839     711199
# ...

# %%
# 전체와 나머지 분리
dt_all = dt_3[dt_3['산업분류'] == '전체']
dt_no_all = dt_3[dt_3['산업분류'] != '전체'].reset_index(drop=True)
dt_no_all
# Out:
#                                  산업분류  18_종사자_전체  19_종사자_전체  20_종사자_전체  \
# 0                         B.광업(05~08)      13380      12889      12338
# 1                        C.제조업(10~34)    3714033    3732281    3666936
# 2        D.전기, 가스, 증기 및 공기 조절 공급업(35)      63529      65687      68608
# 3    E.수도, 하수 및 폐기물 처리, 원료 재생업(36~39)     105290     110367     114745
# 4                        F.건설업(41~42)    1337651    1375391    1382362
# 5                   G.도매 및 소매업(45~47)    2259258    2319243    2268010
# 6                   H.운수 및 창고업(49~52)     721161     731839     711199
# 7                  I.숙박 및 음식점업(55~56)    1224015    1289634    1141450
# 8                      J.정보통신업(58~63)     585773     606581     612776
# 9                   K.금융 및 보험업(64~66)     757618     760292     766636
# 10                         L.부동산업(68)     378137     393998     411815
# 11          M.전문, 과학 및 기술 서비스업(70~73)     990589    1054162    1096987
# ...

# %%
dt_no_all['산업분류'] = dt_no_all['산업분류'].str.split('(', expand=True)[0]
dt_no_all
# Out:
#                           산업분류  18_종사자_전체  19_종사자_전체  20_종사자_전체  21_종사자_전체
# 0                         B.광업      13380      12889      12338      12371
# 1                        C.제조업    3714033    3732281    3666936    3663310
# 2     D.전기, 가스, 증기 및 공기 조절 공급업      63529      65687      68608      70087
# 3    E.수도, 하수 및 폐기물 처리, 원료 재생업     105290     110367     114745     117670
# 4                        F.건설업    1337651    1375391    1382362    1386013
# 5                   G.도매 및 소매업    2259258    2319243    2268010    2277199
# 6                   H.운수 및 창고업     721161     731839     711199     705220
# 7                  I.숙박 및 음식점업    1224015    1289634    1141450    1088150
# 8                      J.정보통신업     585773     606581     612776     660843
# 9                   K.금융 및 보험업     757618     760292     766636     772880
# 10                      L.부동산업     378137     393998     411815     428116
# ...

# %%
dt_no_all.columns = ["산업분류", "2018", "2019", "2020", "2021"]
dt_no_all
# Out:
#                           산업분류     2018     2019     2020     2021
# 0                         B.광업    13380    12889    12338    12371
# 1                        C.제조업  3714033  3732281  3666936  3663310
# 2     D.전기, 가스, 증기 및 공기 조절 공급업    63529    65687    68608    70087
# 3    E.수도, 하수 및 폐기물 처리, 원료 재생업   105290   110367   114745   117670
# 4                        F.건설업  1337651  1375391  1382362  1386013
# 5                   G.도매 및 소매업  2259258  2319243  2268010  2277199
# 6                   H.운수 및 창고업   721161   731839   711199   705220
# 7                  I.숙박 및 음식점업  1224015  1289634  1141450  1088150
# 8                      J.정보통신업   585773   606581   612776   660843
# 9                   K.금융 및 보험업   757618   760292   766636   772880
# 10                      L.부동산업   378137   393998   411815   428116
# 11          M.전문, 과학 및 기술 서비스업   990589  1054162  1096987  1146517
# 12  N.사업시설 관리, 사업 지원 및 임대 서비스업  1159690  1178106  1142366  1118243
# ...

# %%
dt_all.columns = ["산업분류", "2018", "2019", "2020", "2021"]
dt_all
# Out:
#   산업분류      2018      2019      2020      2021
# 0   전체  18148819  18699465  18591325  18773299

# %%
# 년도별 차이를 비율로 구함
dt_18_19 = round(dt_no_all["2019"] / dt_no_all["2018"]-1,3)
dt_19_20 = round(dt_no_all["2020"] / dt_no_all["2019"]-1,3)
dt_20_21 = round(dt_no_all["2021"] / dt_no_all["2020"]-1,3)
dt_20_21 = round(dt_no_all["2021"] / dt_no_all["2020"]-1,3)

# %%
dt_18_21 = round(dt_no_all["2021"] / dt_no_all["2018"]-1,3)
dt_18_21
# Out:
# 0    -0.075
# 1    -0.014
# 2     0.103
# 3     0.118
# 4     0.036
# 5     0.008
# 6    -0.022
# 7    -0.111
# 8     0.128
# 9     0.020
# 10    0.132
# 11    0.157
# 12   -0.036
# 13    0.166
# 14    0.049
# 15    0.184
# 16   -0.056
# 17   -0.004
# dtype: float64

# %%
# 열붙이기
dt_no_all["산업분류"]
dt_f = pd.concat([dt_no_all["산업분류"],dt_18_19,dt_19_20,dt_20_21,dt_18_21], axis=1)
dt_f.columns = ["산업분류", "18-19", "19-20", "20-21", "18-21"]
dt_f
# Out:
#                           산업분류  18-19  19-20  20-21  18-21
# 0                         B.광업 -0.037 -0.043  0.003 -0.075
# 1                        C.제조업  0.005 -0.018 -0.001 -0.014
# 2     D.전기, 가스, 증기 및 공기 조절 공급업  0.034  0.044  0.022  0.103
# 3    E.수도, 하수 및 폐기물 처리, 원료 재생업  0.048  0.040  0.025  0.118
# 4                        F.건설업  0.028  0.005  0.003  0.036
# 5                   G.도매 및 소매업  0.027 -0.022  0.004  0.008
# 6                   H.운수 및 창고업  0.015 -0.028 -0.008 -0.022
# 7                  I.숙박 및 음식점업  0.054 -0.115 -0.047 -0.111
# 8                      J.정보통신업  0.036  0.010  0.078  0.128
# 9                   K.금융 및 보험업  0.004  0.008  0.008  0.020
# 10                      L.부동산업  0.042  0.045  0.040  0.132
# 11          M.전문, 과학 및 기술 서비스업  0.064  0.041  0.045  0.157
# 12  N.사업시설 관리, 사업 지원 및 임대 서비스업  0.016 -0.030 -0.021 -0.036
# 13        O.공공행정, 국방 및 사회보장 행정  0.042  0.128 -0.008  0.166
# 14                   P.교육 서비스업  0.027 -0.008  0.030  0.049
# ...

# %%
#산업분류에 맨앞 영어만 가져와 산업 코드 생성
code_list =[]
for i in range(0,18):
    code_list.append(dt_no_all["산업분류"][i][0])
dt_f["산업분류코드"] = code_list
dt_f[['산업분류','산업분류코드','18-19','19-20','20-21','18-21']]
# Out:
#                           산업분류 산업분류코드  18-19  19-20  20-21  18-21
# 0                         B.광업      B -0.037 -0.043  0.003 -0.075
# 1                        C.제조업      C  0.005 -0.018 -0.001 -0.014
# 2     D.전기, 가스, 증기 및 공기 조절 공급업      D  0.034  0.044  0.022  0.103
# 3    E.수도, 하수 및 폐기물 처리, 원료 재생업      E  0.048  0.040  0.025  0.118
# 4                        F.건설업      F  0.028  0.005  0.003  0.036
# 5                   G.도매 및 소매업      G  0.027 -0.022  0.004  0.008
# 6                   H.운수 및 창고업      H  0.015 -0.028 -0.008 -0.022
# 7                  I.숙박 및 음식점업      I  0.054 -0.115 -0.047 -0.111
# 8                      J.정보통신업      J  0.036  0.010  0.078  0.128
# 9                   K.금융 및 보험업      K  0.004  0.008  0.008  0.020
# 10                      L.부동산업      L  0.042  0.045  0.040  0.132
# 11          M.전문, 과학 및 기술 서비스업      M  0.064  0.041  0.045  0.157
# 12  N.사업시설 관리, 사업 지원 및 임대 서비스업      N  0.016 -0.030 -0.021 -0.036
# ...

# %%
# ylist = np.arange(-0.2,0.3,0.1)

# plt.figure(figsize=(20,10))

# plt.rc('font', family = 'Malgun Gothic', size = 18)

# plt.hlines(xmin=-2,xmax=20, y=0,colors='black',linewidth = 1)

# plt.title('18-19년도 근로자 수 차이비율',fontsize = 20,loc='center', pad=30, fontweight="bold")

# plt.text(-1,0.205, '단위: %', fontsize=15, color = 'black')

# plt.bar(dt_f['산업분류코드'],dt_f['18-19'],width=0.6, color ='#F2B117')

# plt.yticks(ylist)

# for i, v in enumerate(dt_f['산업분류코드']):
#     if dt_f['18-19'][i] > 0 :
#         plt.text(v, dt_f['18-19'][i], dt_f['18-19'][i],
#              fontsize = 15, 
#              color='black',
#              horizontalalignment='center',  # horizontalalignment (left, center, right)
#              verticalalignment='bottom')    # verticalalignment (top, center, bottom)
#     else :
#         plt.text(v, dt_f['18-19'][i], dt_f['18-19'][i],
#              fontsize = 15, 
#              color='black',
#              horizontalalignment='center',  # horizontalalignment (left, center, right)
#              verticalalignment='top') 
        
# plt.show()

# %%
ylist = np.arange(-0.2,0.3,0.1)

fig = plt.figure(figsize=(20,10))

fig.set_facecolor('#EEEEEE')
plt.gca().set_facecolor('#EEEEEE')
plt.rc('font', family = 'Malgun Gothic', size = 18)

plt.hlines(xmin=-2,xmax=20, y=0,colors='black',linewidth = 1)

plt.title('19-20년도 근로자 수 차이비율',fontsize = 20,loc='center', pad=30, fontweight="bold")

plt.text(-1.1,0.205, '단위: %', fontsize=15, color = 'black')

plt.bar(dt_f['산업분류코드'],dt_f['19-20'],width=0.6, color ='#F2B117')

plt.yticks(ylist)

for i, v in enumerate(dt_f['산업분류코드']):
    if dt_f['19-20'][i] > 0 :
        plt.text(v, dt_f['19-20'][i], dt_f['19-20'][i],
             fontsize = 15, 
             color='black',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)
    else :
        plt.text(v, dt_f['19-20'][i], dt_f['19-20'][i],
             fontsize = 15, 
             color='black',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='top') 
        
plt.show()

# %%
ylist = np.arange(-0.2,0.3,0.1)

fig = plt.figure(figsize=(20,10))

fig.set_facecolor('#EEEEEE')
plt.gca().set_facecolor('#EEEEEE')
plt.rc('font', family = 'Malgun Gothic', size = 18)

plt.hlines(xmin=-2,xmax=20, y=0,colors='black',linewidth = 1)

plt.title('20-21년도 근로자 수 차이비율',fontsize = 20,loc='center', pad=30, fontweight="bold")

plt.text(-1,0.205, '단위: %', fontsize=15, color = 'black')

plt.bar(dt_f['산업분류코드'],dt_f['20-21'],width=0.6, color ='#F2B117')

plt.yticks(ylist)

for i, v in enumerate(dt_f['산업분류코드']):
    if dt_f['20-21'][i] > 0 :
        plt.text(v, dt_f['20-21'][i], dt_f['20-21'][i],
             fontsize = 15, 
             color='black',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)
    else :
        plt.text(v, dt_f['20-21'][i], dt_f['20-21'][i],
             fontsize = 15, 
             color='black',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='top') 
        
plt.show()

# %%
# ylist = np.arange(-0.2,0.3,0.1)

# plt.figure(figsize=(20,10))

# plt.rc('font', family = 'Malgun Gothic', size = 18)

# plt.hlines(xmin=-2,xmax=20, y=0,colors='black',linewidth = 1)

# plt.title('18-21년도 근로자 수 차이비율',fontsize = 20,loc='center', pad=30, fontweight="bold")

# plt.text(-1,0.205, '단위: %', fontsize=15, color = 'black')

# plt.bar(dt_f['산업분류코드'],dt_f['18-21'],width=0.6, color ='#F2B117')

# plt.yticks(ylist)

# for i, v in enumerate(dt_f['산업분류코드']):
#     if dt_f['18-21'][i] > 0 :
#         plt.text(v, dt_f['18-21'][i], dt_f['18-21'][i],
#              fontsize = 15, 
#              color='black',
#              horizontalalignment='center',  # horizontalalignment (left, center, right)
#              verticalalignment='bottom')    # verticalalignment (top, center, bottom)
#     else :
#         plt.text(v, dt_f['18-21'][i], dt_f['18-21'][i],
#              fontsize = 15, 
#              color='black',
#              horizontalalignment='center',  # horizontalalignment (left, center, right)
#              verticalalignment='top') 
        
# plt.show()
